# %% [markdown]
# <a href="https://colab.research.google.com/github/thobitz/PricingTest/blob/main/MCDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MCDemo
#
# Monte Carlo Demo

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
n = 1000000 # # Scenarios
S = 8
K = 10
sigma = .2
T = 1.5
r = 0.05

# %%
S_T = S_0 * np.exp(sigma * np.sqrt(T) * np.random.normal(0, 1, size=n))

C = np.maximum(S_T - K, 0).mean()*np.exp(-r*T)
C
# Out:
# np.float64(0.2522216159673457)

# %%
S_T
# Out:
# array([ 9.56038515,  5.9918422 ,  6.15183887, ..., 10.36160338,
#        11.9087646 , 10.38847878])

# %%
np.maximum(S_T - K, 0)
# Out:
# array([0.        , 0.        , 0.        , ..., 0.36160338, 1.9087646 ,
#        0.38847878])

# %%
d1 = (np.log(S/K) + (r+sigma**2/2.0)*T)/(sigma*np.sqrt(T))
d2 = d1 - sigma*np.sqrt(T)
C_bs = S*st.norm.cdf(d1) - K*np.exp(-r*T)*st.norm.cdf(d2)
C_bs
# Out:
# np.float64(0.35174963554263483)

# %%
# Out:
# np.float64(0.5)
